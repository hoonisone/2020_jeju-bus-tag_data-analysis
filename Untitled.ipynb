# %%
import os
import datetime
import pandas as pd
from tqdm import tqdm
from pyarrow import csv

# 사용자 정의
import bus

# %%
start_date = datetime.datetime(2019, 6, 1)
end_date = datetime.datetime(2019, 8, 29)

input_path_list = bus.make_input_path(start_date, end_date)

usage_df = bus.load_total_usage_data(input_path_list)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 89/89 [04:27<00:00,  3.01s/it]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-082fbccd47c2> in <module>
#       5
#       6 usage_df = bus.load_total_usage_data(input_path_list)
# ----> 7 usage_df = data_preprocessing(usage_df)
#
# NameError: name 'data_preprocessing' is not defined

# %%
usage_df.isnull().describe()
# Out:
#          user_id base_date  route_id route_name  route_no geton_datetime  \
# count   12291789  12291789  12291789   12291789  12291789       12291789
# unique         1         1         1          1         1              1
# top        False     False     False      False     False          False
# freq    12291789  12291789  12291789   12291789  12291789       12291789
#
#        geton_station_id geton_stataion_name geton_station_longitude  \
# count          12291789            12291789                12291789
# unique                1                   2                       2
# top               False               False                   False
# freq           12291789            12291596                12290846
#
#        geton_station_latitude getoff_datetime getoff_station_id  \
# count                12291789        12291789          12291789
# unique                      2               2                 2
# top                     False           False             False
# freq                 12291572         7903385           7903385
#
#        getoff_station_name getoff_station_longitude getoff_station_latitude  \
# count             12291789                 12291789                12291789
# unique                   2                        2                       2
# top                  False                    False                   False
# freq               7899621                  7899611                 7899611
#
#        user_type user_count input_date   tourist
# count   12291789   12291789   12291789  12291789
# unique         1          1          1         1
# top        False      False      False     False
# freq    12291789   12291789   12291789  12291789
